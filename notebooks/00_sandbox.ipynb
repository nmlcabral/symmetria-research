# %% [markdown]
# # 00_sandbox
#
# Use this space to scratch ideas before creating a dedicated notebook.

# %%
import sys
print(sys.executable)
# Out:
# /Users/nunocabral/Projects/Symmetria/symmetria-research/.venv/bin/python
